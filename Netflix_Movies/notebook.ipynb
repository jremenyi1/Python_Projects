# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Read in the Netflix CSV as a DataFrame
netflix_df = pd.read_csv("netflix_data.csv")

# Importing numpy as nt
import numpy as np

# Create group of 1990s as decade_movies 
duration = netflix_df[np.logical_and(netflix_df["release_year"] > 1989, netflix_df["release_year"] < 2000)]

# Create histogram of 1990s as decade_movies 
plt.hist(duration["duration"], bins = 40)
plt.show()
plt.clf()

# %% [markdown]
# <center><img src="redpopcorn.jpg"></center>

# %% [markdown]
# **Netflix**! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.
#
# Given the large number of movies and series available on the platform, it is a perfect opportunity to flex your exploratory data analysis skills and dive into the entertainment industry.
#
# You work for a production company that specializes in nostalgic styles. You want to do some research on movies released in the 1990's. You'll delve into Netflix data and perform exploratory data analysis to better understand this awesome movie decade!
#
# You have been supplied with the dataset `netflix_data.csv`, along with the following table detailing the column names and descriptions. Feel free to experiment further after submitting!
#
# ## The data
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | The ID of the show |
# | `type` | Type of show |
# | `title` | Title of the show |
# | `director` | Director of the show |
# | `cast` | Cast of the show |
# | `country` | Country of origin |
# | `date_added` | Date added to Netflix |
# | `release_year` | Year of Netflix release |
# | `duration` | Duration of the show in minutes |
# | `description` | Description of the show |
# | `genre` | Show genre |

# %%
# Start coding here! Use as many cells as you like
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Read in the Netflix CSV as a DataFrame
netflix_df = pd.read_csv("netflix_data.csv", index_col = 0)
larger_1990s = netflix_df["release_year"] >= 1990
netflix_df[larger_1990s]

# Importing numpy as np
import numpy as np

# Create group of 1990s as decade_movies 
duration_df = netflix_df[np.logical_and(netflix_df["release_year"] > 1989, netflix_df["release_year"] < 2000)]

# Create histogram of 1990s as decade_movies 
plt.hist(duration_df["duration"], bins = 30)
plt.show()
plt.clf()

# Approximate answer as an integer called duration
duration = 93
print('duration' + '=' + '95')


# Create group of Action Movies from 1990s as decade_movies 
action_movies = duration_df[duration_df["genre"] == "Action"]
print(action_movies)

# Create a counter from 1990s as short_movie_count
short_movie_count = 0
for index, row in action_movies.iterrows():
    if row["duration"] < 90:
        print('short')
        short_movie_count += 1
    else:
        print('long')
    

print(short_movie_count)
print('short_movie_count' + '=' + '7')
# Out:
# duration=95
#           type  ...   genre
# show_id         ...
# s508     Movie  ...  Action
# s628     Movie  ...  Action
# s688     Movie  ...  Action
# s757     Movie  ...  Action
# s1003    Movie  ...  Action
# s1236    Movie  ...  Action
# s1237    Movie  ...  Action
# s1605    Movie  ...  Action
# s1850    Movie  ...  Action
# s2039    Movie  ...  Action
# s2060    Movie  ...  Action
# s2394    Movie  ...  Action
# s2408    Movie  ...  Action
# s2466    Movie  ...  Action
# s2551    Movie  ...  Action
# s2644    Movie  ...  Action
# s2693    Movie  ...  Action
# s2708    Movie  ...  Action
# s3256    Movie  ...  Action
# s3354    Movie  ...  Action
# s3636    Movie  ...  Action
# s3696    Movie  ...  Action
# s3718    Movie  ...  Action
# s3772    Movie  ...  Action
# s4032    Movie  ...  Action
# s4178    Movie  ...  Action
# s4584    Movie  ...  Action
# s4787    Movie  ...  Action
# s4795    Movie  ...  Action
# s5043    Movie  ...  Action
# s5299    Movie  ...  Action
# ...

# %%
-- Explore the data in the table
SELECT *
FROM SOCCER.TBL_UEFA_2021
LIMIT 50
# Out:
#                           STAGE  ...                           LOCATION
# 0                        Final   ...                            Anfield
# 1       Semi-finals second leg   ...                  Santiago Bernabeu
# 2       Semi-finals second leg   ...                        El Madrigal
# 3        Semi-finals first leg   ...                            Anfield
# 4        Semi-finals first leg   ...                             Etihad
# 5    Quarter-finals second leg   ...       Civitas Metropolitan Stadium
# 6    Quarter-finals second leg   ...                            Anfield
# 7    Quarter-finals second leg   ...                  Santiago Bernabeu
# 8    Quarter-finals second leg   ...                      Allianz Arena
# 9     Quarter-finals first leg   ...                        El Madrigal
# 10    Quarter-finals first leg   ...                    Stamford Bridge
# 11    Quarter-finals first leg   ...  Estádio do Sport Lisboa e Benfica
# ...
