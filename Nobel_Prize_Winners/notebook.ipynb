# %% [markdown]
# The Nobel Prize has been among the most prestigious international awards since 1901. Each year, awards are bestowed in chemistry, literature, physics, physiology or medicine, economics, and peace. In addition to the honor, prestige, and substantial prize money, the recipient also gets a gold medal with an image of Alfred Nobel (1833 - 1896), who established the prize.
#
# ![](Nobel_Prize.png)
#
# The Nobel Foundation has made a dataset available of all prize winners from the outset of the awards from 1901 to 2023. The dataset used in this project is from the Nobel Prize API and is available in the `nobel.csv` file in the `data` folder.
#
# In this project, you'll get a chance to explore and answer several questions related to this prizewinning data. And we encourage you then to explore further questions that you're interested in!

# %%
# Loading in required libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# Start coding here!

# Calculate most commonly awarded gender and birth country
nobel_award_df = pd.read_csv('data/nobel.csv')
print(nobel_award_df.head())
print(nobel_award_df.info)
print(nobel_award_df.columns)

g = sns.countplot(x='sex', data=nobel_award_df)
plt.show(g)

h = sns.countplot(x='birth_country', data=nobel_award_df)
plt.show(h)

count_birth_country = nobel_award_df.value_counts('birth_country')
print(count_birth_country.to_string())

count_gender = nobel_award_df.value_counts('sex')
print(count_gender)

top_gender = "Male"
print(top_gender)

top_country = "United States of America"
print(top_country)

# Alternative solutions
top_gender = nobel_award_df['sex'].value_counts().idxmax()
top_country = nobel_award_df['birth_country'].value_counts().idxmax()

print(top_gender)
print(top_country)

print(nobel_award_df.isna().sum())
# Out:
#    year    category  ... death_city death_country
# 0  1901   Chemistry  ...     Berlin       Germany
# 1  1901  Literature  ...   Châtenay        France
# 2  1901    Medicine  ...    Marburg       Germany
# 3  1901       Peace  ...     Heiden   Switzerland
# 4  1901       Peace  ...      Paris        France
#
# [5 rows x 18 columns]
# <bound method DataFrame.info of      year    category  ... death_city death_country
# 0    1901   Chemistry  ...     Berlin       Germany
# 1    1901  Literature  ...   Châtenay        France
# 2    1901    Medicine  ...    Marburg       Germany
# 3    1901       Peace  ...     Heiden   Switzerland
# 4    1901       Peace  ...      Paris        France
# ..    ...         ...  ...        ...           ...
# 995  2023   Chemistry  ...        NaN           NaN
# 996  2023   Chemistry  ...        NaN           NaN
# 997  2023  Literature  ...        NaN           NaN
# 998  2023       Peace  ...        NaN           NaN
# ...

# %%
# Decade with Highest ratio of US-born Nobel Prize winners
# US_born_winners_df = nobel_award_df.loc[:, ['year', 'birth_country']]
# print(US_born_winners_df)

US_born_winners_df = nobel_award_df.loc[nobel_award_df['birth_country'] == 'United States of America', ['year', 'birth_country', 'category']]
print(US_born_winners_df)

# Round years to the lower 10 (//: divide with integral result (discard remainder))
decade_US_born_winners = ( US_born_winners_df['year'] // 10) * 10
print(decade_US_born_winners)

# Summarize categories in decades
US_born_winners_sum = decade_US_born_winners.value_counts()
print(US_born_winners_sum)

max_decade_usa = 2000
print(max_decade_usa)

decade_total_winners = (nobel_award_df['year']//10) * 10
print(decade_total_winners)

total_winners_sum = decade_total_winners.value_counts()
print(total_winners_sum)


print((US_born_winners_sum/total_winners_sum).sort_values(ascending = False))


'''
#which decade had highest ratio of US-born prize winners

max_ratio = 0
max_decade_usa = 0

for j in range(0, 130, 10):
    US_counter = 0
    total_counter = 0 
    for i in range(0, len(df), 1):
        if (df.iloc[i]["year"] >= 1900 + j) and (df.iloc[i]["year"] < 1910 + j):
            if df.iloc[i]["birth_country"] == "United States of America":
                US_counter += 1
                total_counter += 1
            else:
                total_counter += 1
    if max_ratio < (US_counter / total_counter):
        max_ratio = (US_counter / total_counter)
        max_decade_usa = 1900 + j

    
print(max_decade_usa)
'''
# Out:
#      year             birth_country   category
# 35   1906  United States of America      Peace
# 72   1912  United States of America      Peace
# 79   1914  United States of America  Chemistry
# 95   1919  United States of America      Peace
# 117  1923  United States of America    Physics
# ..    ...                       ...        ...
# 987  2022  United States of America  Economics
# 988  2022  United States of America  Economics
# 990  2023  United States of America   Medicine
# 995  2023  United States of America  Chemistry
# 999  2023  United States of America  Economics
#
# [291 rows x 3 columns]
# 35     1900
# 72     1910
# 79     1910
# 95     1910
# 117    1920
#        ...
# 987    2020
# 988    2020
# 990    2020
# 995    2020
# 999    2020
# Name: year, Length: 291, dtype: int64
# 2000    52
# 1990    42
# 2010    38
# 1970    33
# 1980    31
# 1950    21
# 1960    21
# 2020    18
# 1930    14
# 1940    13
# 1920     4
# 1910     3
# 1900     1
# ...

# %%
print(nobel_award_df.info)
print(nobel_award_df.columns)


# Combination of Decade and Nobel Prize category with highest portion of female laurates
decade_allsex = nobel_award_df.loc[:, ['year', 'category', 'laureate_type', 'sex']]
print(decade_allsex)


female_nobel_df = nobel_award_df.loc[nobel_award_df['sex'] == 'Female', ['year', 'category', 'sex', 'laureate_type']]
print(female_nobel_df)

# Add new column called 'decades' to female_decade_df
female_nobel_df["decades"] = female_nobel_df['year']//10 * 10
print(female_nobel_df)

# Value counts only for one series - "decades"
max_female_decades = female_nobel_df["decades"].value_counts()
print(max_female_decades)

# Value counts only for one series - "category"
df = female_nobel_df["category"].value_counts()
print(df)

# Value counts based on combined data - "decades" and "category"
max_female_decades_cat = female_nobel_df.groupby(["decades", "category"]).size()
print(max_female_decades_cat)

# Add new column called 'decades' to nobel_award_df
nobel_award_df["decades"] = nobel_award_df["year"]//10 * 10
max_female_and_male_decades_cat = nobel_award_df.groupby(["decades", "category"]).size()
print(max_female_and_male_decades_cat)

# Ratio of Female to total award in decade and in category / Ratio of total award in decade and in category, then sort values to descending order
ratio = (max_female_decades_cat / max_female_and_male_decades_cat).sort_values(ascending=False)
print(ratio)

max_female_dict ={2020 : "Literature"}
print(max_female_dict)
# Out:
# <bound method DataFrame.info of      year    category  ... death_city death_country
# 0    1901   Chemistry  ...     Berlin       Germany
# 1    1901  Literature  ...   Châtenay        France
# 2    1901    Medicine  ...    Marburg       Germany
# 3    1901       Peace  ...     Heiden   Switzerland
# 4    1901       Peace  ...      Paris        France
# ..    ...         ...  ...        ...           ...
# 995  2023   Chemistry  ...        NaN           NaN
# 996  2023   Chemistry  ...        NaN           NaN
# 997  2023  Literature  ...        NaN           NaN
# 998  2023       Peace  ...        NaN           NaN
# 999  2023   Economics  ...        NaN           NaN
#
# [1000 rows x 18 columns]>
# Index(['year', 'category', 'prize', 'motivation', 'prize_share', 'laureate_id',
#        'laureate_type', 'full_name', 'birth_date', 'birth_city',
#        'birth_country', 'sex', 'organization_name', 'organization_city',
# ...

# %%
# First woman to receive a Nobel prize and which category

print(nobel_award_df.columns)



# Create new database for only women with the following columns: year, sex, category, full_name
first_female = nobel_award_df.loc[nobel_award_df["sex"] == "Female", ["year", "category", "full_name", "sex"]]
print(first_female)
print(first_female.iloc[0:1, 0:4])

first_woman_name = "Marie Curie, née Sklodowska"
first_woman_category = "Physics"

print(first_woman_name)
print(first_woman_category)
# Out:
# Index(['year', 'category', 'prize', 'motivation', 'prize_share', 'laureate_id',
#        'laureate_type', 'full_name', 'birth_date', 'birth_city',
#        'birth_country', 'sex', 'organization_name', 'organization_city',
#        'organization_country', 'death_date', 'death_city', 'death_country',
#        'decades'],
#       dtype='object')
#      year  ...     sex
# 19   1903  ...  Female
# 29   1905  ...  Female
# 51   1909  ...  Female
# 62   1911  ...  Female
# 128  1926  ...  Female
# ..    ...  ...     ...
# 982  2022  ...  Female
# 989  2023  ...  Female
# 993  2023  ...  Female
# 998  2023  ...  Female
# 999  2023  ...  Female
#
# [65 rows x 4 columns]
#     year category                    full_name     sex
# 19  1903  Physics  Marie Curie, née Sklodowska  Female
# Marie Curie, née Sklodowska
# Physics

# %%
# Individuals or organizations have von more than one Nobel Prize

print(nobel_award_df.columns)

print(nobel_award_df['full_name'].value_counts().head(10))

repeat_list = ["Comité international de la Croix Rouge (International Committee of the Red Cross)", "Linus Carl Pauling", "John Bardeen", "Frederick Sanger", "Marie Curie, née Sklodowska", "Office of the United Nations High Commissioner for Refugees (UNHCR)"]

print(repeat_list)

print(nobel_award_df['organization_name'].value_counts().head(30))
# Out:
# Index(['year', 'category', 'prize', 'motivation', 'prize_share', 'laureate_id',
#        'laureate_type', 'full_name', 'birth_date', 'birth_city',
#        'birth_country', 'sex', 'organization_name', 'organization_city',
#        'organization_country', 'death_date', 'death_city', 'death_country',
#        'decades'],
#       dtype='object')
# Comité international de la Croix Rouge (International Committee of the Red Cross)    3
# Linus Carl Pauling                                                                   2
# John Bardeen                                                                         2
# Frederick Sanger                                                                     2
# Marie Curie, née Sklodowska                                                          2
# Office of the United Nations High Commissioner for Refugees (UNHCR)                  2
# William Vickrey                                                                      1
# ...
